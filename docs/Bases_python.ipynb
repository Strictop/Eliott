# %%
1+1
# Out:
# 2

# %% [markdown]
# {
#
#  « cellules »: [
#
#   {
#
#    « cell_type »: « code »,
#
#    « execution_count »: 4,
#
#    « métadonnées »: {},
#
#    « sorties »: [
#
#     {
#
#      « données »: {
#
#       « texte/brut »: [
#
#        « 'hello world' »
#
#       ]
#
#      },
#
#      « execution_count »: 4,
#
#      « métadonnées »: {},
#
#      « output_type »: « execute_result »
#
#     }
#
#    ],
#
#    « source »: [
#
#     « 'heelo ' + 'monde'\n »,
#
#     « 'hhelo' + 'monde'\n »,
#
#     « 'bonjour' + ' ' + 'monde' »
#
#    ]
#
#   },
#
#   {
#
#    « cell_type »: « code »,
#
#    « execution_count »: 6,
#
#    « métadonnées »: {},
#
#    « sorties »: [
#
#     {
#
#      « données »: {
#
#       « texte/brut »: [
#
#        « 'Bonjour' »
#
#       ]
#
#      },
#
#      « execution_count »: 6,
#
#      « métadonnées »: {},
#
#      « output_type »: « execute_result »
#
#     }
#
#    ],
#
#    « source »: [
#
#     « mot = 'Bonjour'\n »,
#
#     « mot »
#
#    ]
#
#   },
#
#   {
#
#    « cell_type »: « code »,
#
#    « execution_count »: 8,
#
#    « métadonnées »: {},
#
#    « sorties »: [
#
#     {
#
#      « nom »: « stdout »,
#
#      « output_type »: « stream »,
#
#      « texte »: [
#
#       « Au revoir\n »
#
#      ]
#
#     }
#
#    ],
#
#    « source »: [
#
#     « mot = 'Au revoir'\n »,
#
#     « print(mot) »
#
#    ]
#
#   },
#
#   {
#
#    « cell_type »: « code »,
#
#    « execution_count »: 1,
#
#    « métadonnées »: {},
#
#    « sorties »: [
#
#     {
#
#      « nom »: « stdout »,
#
#      « output_type »: « stream »,
#
#      « texte »: [
#
#       « W\n »,
#
#       « o\n »,
#
#       « r\n »,
#
#       « l\n »,
#
#       « d\n »
#
#      ]
#
#     }
#
#    ],
#
#    « source »: [
#
#     « nom = 'Monde'\n »,
#
#     « pour caractere in nom: print(characters) »
#
#    ]
#
#   },
#
#   {
#
#    « cell_type »: « code »,
#
#    « execution_count »: 9,
#
#    « métadonnées »: {},
#
#    « sorties »: [
#
#     {
#
#      « nom »: « stdout »,
#
#      « output_type »: « stream »,
#
#      « texte »: [
#
#       « Monde\n »,
#
#       « Monde\n »,
#
#       « Monde\n »,
#
#       « Monde\n »,
#
#       « Monde\n »
#
#      ]
#
#     }
#
#    ],
#
#    « source »: [
#
#     « nom = 'Monde'\n »,
#
#     « pour _ dans nom:\n »,
#
#     «    print(nom) »
#
#    ]
#
#   },
#
#   {
#
#    « cell_type »: « code »,
#
#    « execution_count »: null,
#
#    « métadonnées »: {},
#
#    « sorties »: [],
#
#    « source »: [... ]
#
#   }
#
#  ],
#
#  « métadonnées »: {
#
#   « kernelspec »: {
#
#    « display_name »: « Python 3.8.13 64 bits ('3.8.13') »,
#
#    « langage »: « python »,
#
#    « nom »: « python3 »
#
#   },
#
#   « language_info »: {
#
#    « codemirror_mode »: {
#
#     « nom »: « ipython »,
#
#     « version »: 3
#
#    },
#
#    « file_extension »: « .py »,
#
#    « mimetype »: « text/x-python »,
#
#    « nom »: « python »,
#
#    « nbconvert_exporter »: « python »,
#
#    « pygments_lexer »: « ipython (3) »,
#
#    « version »: « 3.8.13 »
#
#   },
#
#   « orig_nbformat »: 4,
#
#   « vscode »: {
#
#    « interprète »: {
#
#     « hash »: « 110cc1dee26208153f2972f08a2ad52b6a56238dc66d48e87fb757ef2996db56 »
#
#    }
#
#   }
#
#  },
#
#  « nbformat »: 4,
#
#  « nbformat_minor »: 2
#
# }

# %%
hello = 'Hello'
print(hello)
hello = hello + '!'
print(hello)
# Out:
# Hello
# Hello!
